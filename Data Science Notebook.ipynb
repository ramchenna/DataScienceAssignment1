# %%
library("aws.s3")
# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

obj <- get_object(
    object = "CustomerLoyaltyProgram-1.csv",
    bucket = "firstibmwatsonproject-donotdelete-pr-0vbe9fumdtz1gx",
    key = "7a24b9bf97084f4886b0233cc92d0574",
    secret = "56e34faac72b3389eeaf7b4992492b9efc3ff540803e5738",
    check_region = FALSE,
    region = "",
    base_url = "s3.private.eu-gb.cloud-object-storage.appdomain.cloud"
)

df_1 <- read.csv(text = rawToChar(obj))
library("aws.s3")
# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

obj <- get_object(
    object = "SeoulBikeData.csv",
    bucket = "firstibmwatsonproject-donotdelete-pr-0vbe9fumdtz1gx",
    key = "7a24b9bf97084f4886b0233cc92d0574",
    secret = "56e34faac72b3389eeaf7b4992492b9efc3ff540803e5738",
    check_region = FALSE,
    region = "",
    base_url = "s3.private.eu-gb.cloud-object-storage.appdomain.cloud"
)

df_3 <- read.csv(text = rawToChar(obj))
head(df_3)

library("aws.s3")
# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

obj <- get_object(
    object = "Chicago_Crime_Data-v2.csv",
    bucket = "firstibmwatsonproject-donotdelete-pr-0vbe9fumdtz1gx",
    key = "7a24b9bf97084f4886b0233cc92d0574",
    secret = "56e34faac72b3389eeaf7b4992492b9efc3ff540803e5738",
    check_region = FALSE,
    region = "",
    base_url = "s3.private.eu-gb.cloud-object-storage.appdomain.cloud"
)

df_2 <- read.csv(text = rawToChar(obj))
head(df_2)

head(df_1)
# Out:
#   Date       Rented.Bike.Count Hour Temperature..b0.C. Humidity...
# 1 01/12/2017 254               0    -5.2               37
# 2 01/12/2017 204               1    -5.5               38
# 3 01/12/2017 173               2    -6.0               39
# 4 01/12/2017 107               3    -6.2               40
# 5 01/12/2017  78               4    -6.0               36
# 6 01/12/2017 100               5    -6.4               37
#   Wind.speed..m.s. Visibility..10m. Dew.point.temperature..b0.C.
# 1 2.2              2000             -17.6
# 2 0.8              2000             -17.6
# 3 1.0              2000             -17.7
# 4 0.9              2000             -17.6
# 5 2.3              2000             -18.6
# 6 1.5              2000             -18.7
#   Solar.Radiation..MJ.m2. Rainfall.mm. Snowfall..cm. Seasons Holiday
# 1 0                       0            0             Winter  No Holiday
# 2 0                       0            0             Winter  No Holiday
# ...
